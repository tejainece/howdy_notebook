# %% [markdown]
# Example showing how to use LORA models from Local

# %%
import torch
from diffusers import StableDiffusionPipeline, EulerAncestralDiscreteScheduler
import gc

# %%
lora_path = "./models/lora_1_5/magicalPotions_version1.safetensors"
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16).to("cuda")
pipe.load_lora_weights(lora_path, use_safetensors=True)
#pipe.unet.load_attn_procs(lora_path)
pipe.scheduler = EulerAncestralDiscreteScheduler.from_config(pipe.scheduler.config)
def disabled_safety_checker(images, clip_input):
    if len(images.shape)==4:
        num_images = images.shape[0]
        return images, [False]*num_images
    else:
        return images, False
pipe.safety_checker = disabled_safety_checker

pipe.scheduler
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 lora_path = "./models/lora_1_5/magicalPotions_version1.safetensors"
#       2 pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16).to("cuda")
# ----> 3 pipe.load_lora_weights(lora_path, use_safetensors=True)
#       4 #pipe.unet.load_attn_procs(lora_path)
#       5 pipe.scheduler = EulerAncestralDiscreteScheduler.from_config(pipe.scheduler.config)
#
# File ~/projects/howdy_notebook/venv/lib/python3.11/site-packages/diffusers/loaders.py:946, in LoraLoaderMixin.load_lora_weights(self, pretrained_model_name_or_path_or_dict, **kwargs)
#     925 def load_lora_weights(self, pretrained_model_name_or_path_or_dict: Union[str, Dict[str, torch.Tensor]], **kwargs):
#     926     """
#     927     Load LoRA weights specified in `pretrained_model_name_or_path_or_dict` into `self.unet` and
#     928     `self.text_encoder`.
#    (...)
#     944             See [`~loaders.LoraLoaderMixin.lora_state_dict`].
#     945     """
# --> 946     state_dict, network_alphas = self.lora_state_dict(pretrained_model_name_or_path_or_dict, **kwargs)
#     947     self.load_lora_into_unet(state_dict, network_alphas=network_alphas, unet=self.unet)
#     948     self.load_lora_into_text_encoder(
#     949         state_dict,
#     950         network_alphas=network_alphas,
#     951         text_encoder=self.text_encoder,
#     952         lora_scale=self.lora_scale,
#     953     )
#
# File ~/projects/howdy_notebook/venv/lib/python3.11/site-packages/diffusers/loaders.py:1064, in LoraLoaderMixin.lora_state_dict(cls, pretrained_model_name_or_path_or_dict, **kwargs)
#    1062 except (IOError, safetensors.SafetensorError) as e:
#    1063     if not allow_pickle:
# -> 1064         raise e
#    1065     # try loading non-safetensors weights
#    1066     pass
#
# File ~/projects/howdy_notebook/venv/lib/python3.11/site-packages/diffusers/loaders.py:1061, in LoraLoaderMixin.lora_state_dict(cls, pretrained_model_name_or_path_or_dict, **kwargs)
#    1047 try:
#    1048     model_file = _get_model_file(
#    1049         pretrained_model_name_or_path_or_dict,
#    1050         weights_name=weight_name or LORA_WEIGHT_NAME_SAFE,
#    (...)
#    1059         user_agent=user_agent,
#    1060     )
# -> 1061     state_dict = safetensors.torch.load_file(model_file, device="cpu")
#    1062 except (IOError, safetensors.SafetensorError) as e:
#    1063     if not allow_pickle:
#
# File ~/projects/howdy_notebook/venv/lib/python3.11/site-packages/safetensors/torch.py:309, in load_file(filename, device)
#     286 """
#     287 Loads a safetensors file into torch format.
#     288
#    (...)
#     306 ```
#     307 """
#     308 result = {}
# --> 309 with safe_open(filename, framework="pt", device=device) as f:
#     310     for k in f.keys():
#     311         result[k] = f.get_tensor(k)
#
# SafetensorError: Error while deserializing header: HeaderTooLarge

# %%
prompt = "A pokemon with (blue eyesballs:1.9)"
neg_prompt = "low quality, watermark, blue body, blue jaws"
image = pipe(prompt, negative_prompt=neg_prompt, width=512, height=512, num_inference_steps=30).images[0]
image
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from random import SystemRandom
randr = SystemRandom()
#randr.randrange(0xFFFFFFFFFFFFFFFF)

import requests
from PIL import Image
from io import BytesIO
from math import ceil

def flex_grid(imgs, cols):
  rows=ceil(len(imgs)/cols)

  w, h = imgs[0].size
  grid = Image.new('RGB', size=(cols*w, rows*h))

  for i, img in enumerate(imgs):
      grid.paste(img, box=(i%cols*w, i//cols*h))
  return grid

# %%
num_cols = 3
num_images = 6

images = []
for i in range(num_images):
  seed = randr.randrange(0xFFFFFFFFFFFFFFFF)
  print(f'Generating {i + 1} of {num_images} with seed = {seed}')
  generator = torch.Generator("cuda").manual_seed(seed)
  images.extend(pipe(prompt, negative_prompt=neg_prompt, num_inference_steps=30, generator=generator).images)
grid = flex_grid(images, cols=num_cols)
grid
# Out:
# Generating 1 of 6 with seed = 13917040293122347357
#   0%|          | 0/30 [00:00<?, ?it/s]
# Generating 2 of 6 with seed = 5596612288767038365
#   0%|          | 0/30 [00:00<?, ?it/s]
# Generating 3 of 6 with seed = 3094873760267712636
#   0%|          | 0/30 [00:00<?, ?it/s]
# Generating 4 of 6 with seed = 11353349484412553741
#   0%|          | 0/30 [00:00<?, ?it/s]
# Generating 5 of 6 with seed = 2684011896734316865
#   0%|          | 0/30 [00:00<?, ?it/s]
# Generating 6 of 6 with seed = 18350817849730559855
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1536x1024>

# %%
if 'grid' in globals():
    del grid
if 'images' in globals():
    del images
if 'image' in globals():
    del image
if 'pipe' in globals():
    del pipe
gc.collect()
torch.cuda.empty_cache()
print(torch.cuda.memory_summary(device=None, abbreviated=False))
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   8320 KiB |   3256 MiB |   8374 GiB |   8374 GiB |
# |       from large pool |   8320 KiB |   3181 MiB |   8211 GiB |   8211 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   8320 KiB |   3256 MiB |   8374 GiB |   8374 GiB |
# |       from large pool |   8320 KiB |   3181 MiB |   8211 GiB |   8211 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |   8320 KiB |   3231 MiB |   8246 GiB |   8246 GiB |
# |       from large pool |   8320 KiB |   3156 MiB |   8084 GiB |   8084 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  20480 KiB |   3506 MiB |   3506 MiB |   3486 MiB |
# |       from large pool |  20480 KiB |   3420 MiB |   3420 MiB |   3400 MiB |
# |       from small pool |      0 KiB |     86 MiB |     86 MiB |     86 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  12160 KiB | 607059 KiB |   8895 GiB |   8895 GiB |
# |       from large pool |  12160 KiB | 573328 KiB |   8715 GiB |   8715 GiB |
# |       from small pool |      0 KiB |  33767 KiB |    179 GiB |    179 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |       1    |    1565    |    1526 K  |    1526 K  |
# |       from large pool |       1    |     447    |     756 K  |     756 K  |
# |       from small pool |       0    |    1130    |     770 K  |     770 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |       1    |    1565    |    1526 K  |    1526 K  |
# |       from large pool |       1    |     447    |     756 K  |     756 K  |
# |       from small pool |       0    |    1130    |     770 K  |     770 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       1    |     157    |     157    |     156    |
# |       from large pool |       1    |     114    |     114    |     113    |
# |       from small pool |       0    |      43    |      43    |      43    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       2    |      65    |     850 K  |     850 K  |
# |       from large pool |       2    |      34    |     566 K  |     566 K  |
# |       from small pool |       0    |      38    |     284 K  |     284 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
print(torch.cuda.memory_summary(device=None, abbreviated=False))
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   8320 KiB |   3256 MiB |   8374 GiB |   8374 GiB |
# |       from large pool |   8320 KiB |   3181 MiB |   8211 GiB |   8211 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   8320 KiB |   3256 MiB |   8374 GiB |   8374 GiB |
# |       from large pool |   8320 KiB |   3181 MiB |   8211 GiB |   8211 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |   8320 KiB |   3231 MiB |   8246 GiB |   8246 GiB |
# |       from large pool |   8320 KiB |   3156 MiB |   8084 GiB |   8084 GiB |
# |       from small pool |      0 KiB |     81 MiB |    162 GiB |    162 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  20480 KiB |   3506 MiB |   3506 MiB |   3486 MiB |
# |       from large pool |  20480 KiB |   3420 MiB |   3420 MiB |   3400 MiB |
# |       from small pool |      0 KiB |     86 MiB |     86 MiB |     86 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  12160 KiB | 607059 KiB |   8895 GiB |   8895 GiB |
# |       from large pool |  12160 KiB | 573328 KiB |   8715 GiB |   8715 GiB |
# |       from small pool |      0 KiB |  33767 KiB |    179 GiB |    179 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |       1    |    1565    |    1526 K  |    1526 K  |
# |       from large pool |       1    |     447    |     756 K  |     756 K  |
# |       from small pool |       0    |    1130    |     770 K  |     770 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |       1    |    1565    |    1526 K  |    1526 K  |
# |       from large pool |       1    |     447    |     756 K  |     756 K  |
# |       from small pool |       0    |    1130    |     770 K  |     770 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       1    |     157    |     157    |     156    |
# |       from large pool |       1    |     114    |     114    |     113    |
# |       from small pool |       0    |      43    |      43    |      43    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       2    |      65    |     850 K  |     850 K  |
# |       from large pool |       2    |      34    |     566 K  |     566 K  |
# |       from small pool |       0    |      38    |     284 K  |     284 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
